# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import os
import json
from joblib import dump

# %% [markdown]
# # Configuration & Constants

# %%
TARGET_CRS = "EPSG:32648"

# LSTM Sequence Generation
SEQUENCE_LENGTH = 10  # Length of input sequence for LSTM
PREDICTION_HORIZON = 1  # How many steps ahead to predict (e.g., 1 means next step)

# --- File Paths (assuming they are in the same directory or provide full paths) ---
GRID_FEATURES_PATH = "./GIS/danang_grid_with_features.parquet"
MOVEMENT_DATA_PATH = "./HistoricalMovement/danang_movement_processed_decrypted.parquet"
GOOGLE_TIMELINE_DATA_PATH = "./HistoricalMovement/danang_movement_google_timeline.parquet"
HISTORICAL_WEATHER_PATH = (
    "./WeatherForecast/danang_historical_weather_oikolab_processed.csv"
)
AI_READY_DIR = "ai_ready_data_regression" # New directory for regression data

# %% [markdown]
# # Load briefly Pre-processed Data

# %%
grid_gdf = gpd.read_parquet(GRID_FEATURES_PATH)
original_df = pd.read_parquet(MOVEMENT_DATA_PATH)
google_df = pd.read_parquet(GOOGLE_TIMELINE_DATA_PATH)
movement_df = pd.concat([original_df, google_df], ignore_index=True)
print(f"Combined movement dataset size: {movement_df.shape}")
historical_weather_df = pd.read_csv(HISTORICAL_WEATHER_PATH)
# Out:
# Combined movement dataset size: (20905, 10)

# %% [markdown]
# # Further Processing and Feature Engineering

# %% [markdown]
# ### GIS Data

# %%
# Ensure grid_gdf has 'grid_id' as a column for merging
if grid_gdf.index.name == "grid_id":
    grid_gdf.reset_index(inplace=True)

# %% [markdown]
# ### Weather Data

# %%
historical_weather_df["timestamp_utc"] = pd.to_datetime(historical_weather_df["timestamp_utc"], utc=True)
weather_df_processed = historical_weather_df.set_index("timestamp_utc")
weather_cols_to_normalize = ["temp_c", "relative_humidity", "wind_speed_mps", "cloud_cover", "precip_mm"]
weather_cols_present = [col for col in weather_cols_to_normalize if col in weather_df_processed.columns]
if weather_cols_present:
    scaler_weather = MinMaxScaler()
    weather_df_processed[weather_cols_present] = scaler_weather.fit_transform(weather_df_processed[weather_cols_present])

# %% [markdown]
# ### Movement Data

# %%
movement_df["TimestampUTC"] = pd.to_datetime(movement_df["TimestampUTC"], errors='coerce', utc=True)
movement_df.dropna(subset=["TimestampUTC", "Latitude", "Longitude"], inplace=True)
movement_gdf = gpd.GeoDataFrame(
    movement_df,
    geometry=gpd.points_from_xy(movement_df.Longitude, movement_df.Latitude),
    crs="EPSG:4326"
).to_crs(TARGET_CRS)

# %% [markdown]
# ### Spatial join with Grid

# %%
movement_with_grid = gpd.sjoin(movement_gdf, grid_gdf[["grid_id", "geometry"]], how="inner", predicate="within")
if "index_right" in movement_with_grid.columns:
    movement_with_grid.drop(columns=["index_right"], inplace=True)

# Add cyclical time features for movement
dt_col = movement_with_grid["TimestampUTC"]
movement_with_grid["hour_sin_mov"] = np.sin(2 * np.pi * dt_col.dt.hour / 24)
movement_with_grid["hour_cos_mov"] = np.cos(2 * np.pi * dt_col.dt.hour / 24)
movement_with_grid["day_of_week_sin_mov"] = np.sin(2 * np.pi * dt_col.dt.dayofweek / 7)
movement_with_grid["day_of_week_cos_mov"] = np.cos(2 * np.pi * dt_col.dt.dayofweek / 7)

print("\n--- Creating Categorical Feature Indices ---")
# For grid_id
grid_id_encoder = LabelEncoder()
grid_gdf['grid_id_encoded'] = grid_id_encoder.fit_transform(grid_gdf['grid_id'])

# The 'dominant_building_type' column was removed during one-hot encoding in GIS.ipynb.
# We will recreate it here from the existing 'btype_*' columns.
btype_cols = [col for col in grid_gdf.columns if col.startswith('btype_')]
# Use idxmax to get the column name (which represents the type) for the 'True' value in each row
grid_gdf['dominant_building_type'] = grid_gdf[btype_cols].idxmax(axis=1)

# Now we can safely encode the recreated column
building_type_encoder = LabelEncoder()
grid_gdf['btype_encoded'] = building_type_encoder.fit_transform(grid_gdf['dominant_building_type'])
# --- END FIX ---

print(f"Encoded {len(grid_id_encoder.classes_)} unique grid_ids.")
print(f"Encoded {len(building_type_encoder.classes_)} unique building types.")
# Out:
# --- Creating Categorical Feature Indices ---
# Encoded 212350 unique grid_ids.
# Encoded 32 unique building types.

# %% [markdown]
# # Merging Data

# %%
merged_df = pd.merge(movement_with_grid, grid_gdf.drop(columns=["geometry"], errors="ignore"), on="grid_id", how="left")
merged_df["timestamp_round_hour_utc"] = merged_df["TimestampUTC"].dt.round("h")
merged_df = merged_df.sort_values("timestamp_round_hour_utc")
weather_df_processed = weather_df_processed.sort_index()
merged_df = pd.merge_asof(
    merged_df,
    weather_df_processed,
    left_on="timestamp_round_hour_utc",
    right_index=True,
    direction="nearest"
)
print(f"Final merged data shape before sequencing: {merged_df.shape}")
# Out:
# Final merged data shape before sequencing: (20874, 280)

# %% [markdown]
# # Sequence Generation

# %%
merged_df.sort_values(by=["DeviceID", "TimestampUTC"], inplace=True)

# Define feature columns
numeric_feature_cols = weather_cols_present + ["hour_sin", "hour_cos", "day_of_week_sin", "day_of_week_cos",
                                               "hour_sin_mov", "hour_cos_mov", "day_of_week_sin_mov", "day_of_week_cos_mov"]
categorical_feature_cols = ['grid_id_encoded', 'btype_encoded']
target_cols = ["Latitude", "Longitude"]

# Ensure all feature columns are present and fill NaNs
all_feature_cols = numeric_feature_cols + categorical_feature_cols
merged_df[all_feature_cols] = merged_df[all_feature_cols].fillna(0)

sequences_numeric = []
sequences_grid_id = []
sequences_btype = []
targets = []

for device_id, group in merged_df.groupby("DeviceID"):
    # Extract values for each feature type
    numeric_vals = group[numeric_feature_cols].values
    grid_id_vals = group['grid_id_encoded'].values
    btype_vals = group['btype_encoded'].values
    target_vals = group[target_cols].values

    if len(group) >= SEQUENCE_LENGTH + PREDICTION_HORIZON:
        for i in range(len(group) - SEQUENCE_LENGTH - PREDICTION_HORIZON + 1):
            sequences_numeric.append(numeric_vals[i : i + SEQUENCE_LENGTH])
            sequences_grid_id.append(grid_id_vals[i : i + SEQUENCE_LENGTH])
            sequences_btype.append(btype_vals[i : i + SEQUENCE_LENGTH])
            targets.append(target_vals[i + SEQUENCE_LENGTH + PREDICTION_HORIZON - 1])

# Convert to numpy arrays
X_numeric = np.array(sequences_numeric, dtype=np.float32)
X_grid_id = np.array(sequences_grid_id, dtype=np.int32)
X_btype = np.array(sequences_btype, dtype=np.int32)
y = np.array(targets, dtype=np.float32)

print(f"Generated {len(y)} sequences.")
print(f"X_numeric shape: {X_numeric.shape}")
print(f"X_grid_id shape: {X_grid_id.shape}")
print(f"X_btype shape: {X_btype.shape}")
print(f"y shape: {y.shape}")
# Out:
# Generated 20840 sequences.
# X_numeric shape: (20840, 10, 13)
# X_grid_id shape: (20840, 10)
# X_btype shape: (20840, 10)
# y shape: (20840, 2)

# %% [markdown]
# # Data Splitting and Scaling

# %%
train_size = int(0.7 * len(X_numeric))
val_size = int(0.15 * len(X_numeric))

# Split all X and y arrays
X_train_num, X_val_num, X_test_num = X_numeric[:train_size], X_numeric[train_size:train_size+val_size], X_numeric[train_size+val_size:]
X_train_grid, X_val_grid, X_test_grid = X_grid_id[:train_size], X_grid_id[train_size:train_size+val_size], X_grid_id[train_size+val_size:]
X_train_btype, X_val_btype, X_test_btype = X_btype[:train_size], X_btype[train_size:train_size+val_size], X_btype[train_size+val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size+val_size], y[train_size+val_size:]

# Scale numeric features
feature_scaler = MinMaxScaler()
X_train_num_scaled = feature_scaler.fit_transform(X_train_num.reshape(-1, X_train_num.shape[2])).reshape(X_train_num.shape)
X_val_num_scaled = feature_scaler.transform(X_val_num.reshape(-1, X_val_num.shape[2])).reshape(X_val_num.shape)
X_test_num_scaled = feature_scaler.transform(X_test_num.reshape(-1, X_test_num.shape[2])).reshape(X_test_num.shape)

# Scale targets
target_scaler = MinMaxScaler()
y_train_scaled = target_scaler.fit_transform(y_train)
y_val_scaled = target_scaler.transform(y_val)
y_test_scaled = target_scaler.transform(y_test)
print("Applied MinMax scaling to numeric features and targets.")
# Out:
# Applied MinMax scaling to numeric features and targets.

# %% [markdown]
# # Saving the AI-ready data

# %%
if not os.path.exists(AI_READY_DIR):
    os.makedirs(AI_READY_DIR)

# Save numeric data
np.save(os.path.join(AI_READY_DIR, "X_train_numeric.npy"), X_train_num_scaled)
np.save(os.path.join(AI_READY_DIR, "X_val_numeric.npy"), X_val_num_scaled)
np.save(os.path.join(AI_READY_DIR, "X_test_numeric.npy"), X_test_num_scaled)

# Save categorical data
np.save(os.path.join(AI_READY_DIR, "X_train_grid_id.npy"), X_train_grid)
np.save(os.path.join(AI_READY_DIR, "X_val_grid_id.npy"), X_val_grid)
np.save(os.path.join(AI_READY_DIR, "X_test_grid_id.npy"), X_test_grid)

np.save(os.path.join(AI_READY_DIR, "X_train_btype.npy"), X_train_btype)
np.save(os.path.join(AI_READY_DIR, "X_val_btype.npy"), X_val_btype)
np.save(os.path.join(AI_READY_DIR, "X_test_btype.npy"), X_test_btype)

# Save targets
np.save(os.path.join(AI_READY_DIR, "y_train.npy"), y_train_scaled)
np.save(os.path.join(AI_READY_DIR, "y_val.npy"), y_val_scaled)
np.save(os.path.join(AI_READY_DIR, "y_test.npy"), y_test_scaled)

# Save scalers and encoders
dump(feature_scaler, os.path.join(AI_READY_DIR, 'feature_scaler.joblib'))
dump(target_scaler, os.path.join(AI_READY_DIR, 'target_scaler.joblib'))
dump(grid_id_encoder, os.path.join(AI_READY_DIR, 'grid_id_encoder.joblib'))
dump(building_type_encoder, os.path.join(AI_READY_DIR, 'btype_encoder.joblib'))

# Save vocab sizes for the model
vocab_info = {
    'grid_id_vocab_size': len(grid_id_encoder.classes_),
    'btype_vocab_size': len(building_type_encoder.classes_)
}
with open(os.path.join(AI_READY_DIR, "vocab_info.json"), "w") as f:
    json.dump(vocab_info, f)

print("Saved all AI-ready data, scalers, and encoders successfully.")
# Out:
# Saved all AI-ready data, scalers, and encoders successfully.
