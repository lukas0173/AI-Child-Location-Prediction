# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import json

# %% [markdown]
# # Configuration & Constants

# %%
TARGET_CRS = "EPSG:32648"

# LSTM Sequence Generation
SEQUENCE_LENGTH = 10  # Length of input sequence for LSTM
PREDICTION_HORIZON = 1  # How many steps ahead to predict (e.g., 1 means next step)

# --- File Paths (assuming they are in the same directory or provide full paths) ---
GRID_FEATURES_PATH = "./GIS/danang_grid_with_features.parquet"
MOVEMENT_DATA_PATH = "./HistoricalMovement/danang_movement_processed_decrypted.parquet"
GOOGLE_TIMELINE_DATA_PATH = "./HistoricalMovement/danang_movement_google_timeline.parquet"
HISTORICAL_WEATHER_PATH = (
    "./WeatherForecast/danang_historical_weather_oikolab_processed.csv"
)
AI_READY_DIR = "ai_ready_data_regression" # New directory for regression data

# %% [markdown]
# # Load briefly Pre-processed Data

# %%
grid_gdf = gpd.read_parquet(GRID_FEATURES_PATH)
if "grid_id" in grid_gdf.columns and grid_gdf["grid_id"].is_unique:
    grid_gdf = grid_gdf.set_index("grid_id")

original_df = pd.read_parquet(MOVEMENT_DATA_PATH)
google_df = pd.read_parquet(GOOGLE_TIMELINE_DATA_PATH)
movement_df = pd.concat([original_df, google_df], ignore_index=True)
print(f"Combined movement dataset size: {movement_df.shape}")

historical_weather_df = pd.read_csv(HISTORICAL_WEATHER_PATH)
# Out:
# Combined movement dataset size: (20905, 10)

# %% [markdown]
# # Further Processing and Feature Engineering

# %% [markdown]
# ### GIS Data

# %%
gis_cols_to_normalize = [col for col in grid_gdf.columns if "count" in col or "density" in col or "length" in col]
gis_numeric_cols_to_normalize = [col for col in gis_cols_to_normalize if pd.api.types.is_numeric_dtype(grid_gdf[col])]
if gis_numeric_cols_to_normalize:
    scaler_gis = MinMaxScaler()
    grid_gdf[gis_numeric_cols_to_normalize] = scaler_gis.fit_transform(grid_gdf[gis_numeric_cols_to_normalize])

# %% [markdown]
# ### Weather Data

# %%
historical_weather_df["timestamp_utc"] = pd.to_datetime(historical_weather_df["timestamp_utc"], utc=True)
weather_df_processed = historical_weather_df.set_index("timestamp_utc")
weather_cols_to_normalize = ["temp_c", "relative_humidity", "wind_speed_mps", "cloud_cover", "precip_mm"]
weather_cols_present = [col for col in weather_cols_to_normalize if col in weather_df_processed.columns]
if weather_cols_present:
    scaler_weather = MinMaxScaler()
    weather_df_processed[weather_cols_present] = scaler_weather.fit_transform(weather_df_processed[weather_cols_present])

# %% [markdown]
# ### Movement Data

# %%
movement_df["TimestampUTC"] = pd.to_datetime(movement_df["TimestampUTC"], errors='coerce', utc=True)
movement_df.dropna(subset=["TimestampUTC", "Latitude", "Longitude"], inplace=True)
movement_gdf = gpd.GeoDataFrame(
    movement_df,
    geometry=gpd.points_from_xy(movement_df.Longitude, movement_df.Latitude),
    crs="EPSG:4326"
).to_crs(TARGET_CRS)

# %% [markdown]
# ### Spatial join with Grid

# %%
if grid_gdf.index.name == "grid_id":
    grid_gdf_for_join = grid_gdf.reset_index()
else:
    grid_gdf_for_join = grid_gdf
movement_with_grid = gpd.sjoin(movement_gdf, grid_gdf_for_join[["grid_id", "geometry"]], how="left", predicate="within")
movement_with_grid.dropna(subset=["grid_id"], inplace=True)
if "index_right" in movement_with_grid.columns:
    movement_with_grid.drop(columns=["index_right"], inplace=True)

# Add cyclical time features for movement
dt_col = movement_with_grid["TimestampUTC"]
movement_with_grid["hour_sin_mov"] = np.sin(2 * np.pi * dt_col.dt.hour / 24)
movement_with_grid["hour_cos_mov"] = np.cos(2 * np.pi * dt_col.dt.hour / 24)
movement_with_grid["day_of_week_sin_mov"] = np.sin(2 * np.pi * dt_col.dt.dayofweek / 7)
movement_with_grid["day_of_week_cos_mov"] = np.cos(2 * np.pi * dt_col.dt.dayofweek / 7)

# %% [markdown]
# # Merging Data

# %%
if grid_gdf.index.name == "grid_id":
    grid_gdf.reset_index(inplace=True)

merged_df = pd.merge(movement_with_grid, grid_gdf.drop(columns=["geometry"], errors="ignore"), on="grid_id", how="left")
merged_df["timestamp_round_hour_utc"] = merged_df["TimestampUTC"].dt.round("h")
merged_df = merged_df.sort_values("timestamp_round_hour_utc")
weather_df_processed = weather_df_processed.sort_index()
merged_df = pd.merge_asof(
    merged_df,
    weather_df_processed,
    left_on="timestamp_round_hour_utc",
    right_index=True,
    direction="nearest"
)
print(f"Final merged data shape before sequencing: {merged_df.shape}")
# Out:
# /tmp/ipykernel_13793/1541923520.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   grid_gdf.reset_index(inplace=True)
# Final merged data shape before sequencing: (20874, 277)

# %% [markdown]
# # Sequence Generation

# %%
# Sort data is crucial
merged_df.sort_values(by=["DeviceID", "TimestampUTC"], inplace=True)

# Define feature columns (same as before)
gis_feature_columns = [col for col in grid_gdf.columns if col.startswith(("btype_", "poi_count_", "building_count_", "density", "length")) and col != "geometry"]
weather_feature_columns = weather_cols_present + ["hour_sin", "hour_cos", "day_of_week_sin", "day_of_week_cos"]
movement_time_features = ["hour_sin_mov", "hour_cos_mov", "day_of_week_sin_mov", "day_of_week_cos_mov"]
feature_columns = sorted(list(set(gis_feature_columns + weather_feature_columns + movement_time_features)))

# Define target columns
target_columns = ["Latitude", "Longitude"]

# Fill NaNs in feature columns with 0 before creating sequences
merged_df[feature_columns] = merged_df[feature_columns].fillna(0)

# Create sequences
sequences = []
targets = []
device_ids_for_sequences = []

for device_id, group in merged_df.groupby("DeviceID"):
    feature_values = group[feature_columns].values
    target_values = group[target_columns].values # MODIFIED: Target is now lat/lon

    if len(feature_values) >= SEQUENCE_LENGTH + PREDICTION_HORIZON:
        for i in range(len(feature_values) - SEQUENCE_LENGTH - PREDICTION_HORIZON + 1):
            sequences.append(feature_values[i : i + SEQUENCE_LENGTH])
            targets.append(target_values[i + SEQUENCE_LENGTH + PREDICTION_HORIZON - 1])
            device_ids_for_sequences.append(device_id)

X = np.array(sequences, dtype=np.float32)
y = np.array(targets, dtype=np.float32)
print(f"Generated {len(X)} sequences.")
print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Generated 20840 sequences.
# X shape: (20840, 10, 246), y shape: (20840, 2)

# %% [markdown]
# # Data Splitting and Scaling

# %%
train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))

X_train, y_train = X[:train_size], y[:train_size]
X_val, y_val = X[train_size : train_size + val_size], y[train_size : train_size + val_size]
X_test, y_test = X[train_size + val_size :], y[train_size + val_size :]

print(f"Split data chronologically: Train ({len(X_train)}), Val ({len(X_val)}), Test ({len(X_test)})")

# Reshape X for scaling
n_samples_train, timesteps_train, n_features_train = X_train.shape
X_train_reshaped = X_train.reshape(-1, n_features_train)

# Scale features (X)
feature_scaler = MinMaxScaler()
X_train_scaled_reshaped = feature_scaler.fit_transform(X_train_reshaped)
X_train_scaled = X_train_scaled_reshaped.reshape(n_samples_train, timesteps_train, n_features_train)

# Scale targets (y)
target_scaler = MinMaxScaler()
y_train_scaled = target_scaler.fit_transform(y_train)

# Apply scaling to Val and Test sets
n_samples_val, timesteps_val, n_features_val = X_val.shape
X_val_scaled = feature_scaler.transform(X_val.reshape(-1, n_features_val)).reshape(n_samples_val, timesteps_val, n_features_val)
y_val_scaled = target_scaler.transform(y_val)

n_samples_test, timesteps_test, n_features_test = X_test.shape
X_test_scaled = feature_scaler.transform(X_test.reshape(-1, n_features_test)).reshape(n_samples_test, timesteps_test, n_features_test)
y_test_scaled = target_scaler.transform(y_test)

print("Applied MinMax scaling to both features (X) and targets (y).")
# Out:
# Split data chronologically: Train (14587), Val (3126), Test (3127)
# Applied MinMax scaling to both features (X) and targets (y).

# %% [markdown]
# # Saving the AI-ready data

# %%
if not os.path.exists(AI_READY_DIR):
    os.makedirs(AI_READY_DIR)

np.save(os.path.join(AI_READY_DIR, "X_train.npy"), X_train_scaled)
np.save(os.path.join(AI_READY_DIR, "y_train.npy"), y_train_scaled)
np.save(os.path.join(AI_READY_DIR, "X_val.npy"), X_val_scaled)
np.save(os.path.join(AI_READY_DIR, "y_val.npy"), y_val_scaled)
np.save(os.path.join(AI_READY_DIR, "X_test.npy"), X_test_scaled)
np.save(os.path.join(AI_READY_DIR, "y_test.npy"), y_test_scaled)

# Save the scalers for inverse transformation later
from joblib import dump
dump(feature_scaler, os.path.join(AI_READY_DIR, 'feature_scaler.joblib'))
dump(target_scaler, os.path.join(AI_READY_DIR, 'target_scaler.joblib'))

print("Saved AI-ready data and scalers successfully.")
# Out:
# Saved AI-ready data and scalers successfully.
